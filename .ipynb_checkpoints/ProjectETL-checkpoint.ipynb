# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import csv
import json
import numpy as np

# %%
# Read CSV into dataframe
shelterCSV = "Resources/aac_intakes_outcomes.csv"
shelter_df = pd.read_csv(shelterCSV)

# %%
# Read JSON into dataframe
# breedJSON = "Resources/breed_info_2.json"
with open('Resources/breed_info.json', 'r') as f:
    pets_attr_dict = json.load(f)
    
dogs_attr_dict = pets_attr_dict["dog_breeds"]
dogs_attr_dict

dogs_df = pd.DataFrame.from_dict(dogs_attr_dict)
dogs_df = dogs_df.transpose()
dogs_df = dogs_df.reset_index()
dogs_df.rename(columns={'index':'Breed'}, inplace=True)

# Rename Columns
dogs_df = dogs_df.rename(columns={" Adaptability":"Adaptability"," All Around Friendliness":"All Around Friendliness"})

# dogs_cols = ["Breed"," Adaptability"," All Around Friendliness"]
# dogs_df = dogs_df[dogs_cols].copy()

dogs_df.head()
# Out:
#               Breed  Adaptability  All Around Friendliness   Exercise Needs  \
# 0     Affenpinscher           3.0                      3.0              4.0
# 1      Afghan Hound           4.0                      4.0              4.0
# 2  Airedale Terrier           2.0                      4.0              5.0
# 3             Akita           3.0                      2.0              4.0
# 4  Alaskan Klee Kai           3.0                      3.0              4.0
#
#     Health Grooming   Trainability  Adapts Well to Apartment Living  \
# 0               2.0            3.0                              5.0
# 1               2.0            3.0                              5.0
# 2               3.0            5.0                              1.0
# 3               4.0            4.0                              2.0
# 4               3.0            4.0                              3.0
#
#    Affectionate with Family  Amount Of Shedding  Dog Friendly  \
# 0                       5.0                 1.0           4.0
# 1                       5.0                 4.0           4.0
# 2                       4.0                 2.0           4.0
# 3                       5.0                 5.0           1.0
# 4                       4.0                 4.0           2.0
#
#            ...           Potential For Playfulness  Potential For Weight Gain  \
# 0          ...                                 4.0                        3.0
# 1          ...                                 4.0                        1.0
# 2          ...                                 5.0                        4.0
# 3          ...                                 5.0                        4.0
# 4          ...                                 4.0                        2.0
#
#    Prey Drive  Sensitivity Level  Size  Tendency To Bark Or Howl  \
# 0         3.0                3.0   1.0                       2.0
# 1         5.0                5.0   4.0                       2.0
# 2         5.0                3.0   3.0                       4.0
# 3         4.0                5.0   4.0                       5.0
# 4         5.0                4.0   2.0                       3.0
#
#    Tolerates Being Alone  Tolerates Cold Weather  Tolerates Hot Weather  \
# 0                    1.0                     3.0                    3.0
# 1                    2.0                     5.0                    5.0
# 2                    2.0                     3.0                    3.0
# 3                    1.0                     5.0                    2.0
# 4                    2.0                     5.0                    2.0
#
#    Wanderlust Potential
# 0                   2.0
# 1                   5.0
# 2                   4.0
# 3                   4.0
# 4                   4.0
#
# [5 rows x 32 columns]

# %%
# Make List for Column Categories and Copy into dataframe
shelter_cols = ["breed","animal_type","age_upon_outcome_(days)","outcome_type","sex_upon_outcome","time_in_shelter_days"]
Shelter_df = shelter_df[shelter_cols].copy()

# Drop Data That Isn't Related to Dogs
Shelter_df = Shelter_df[Shelter_df.animal_type != 'Cat']
Shelter_df = Shelter_df[Shelter_df.animal_type != 'Other']

# Rename Columns
Shelter_df = Shelter_df.rename(columns={"age_upon_outcome_(days)":"outcome_age_days",
                                        "sex_upon_outcome":"gender"})

# Added more specific age of intake using exact 'time_in_shelter_days' 
Shelter_df['intake_age_days'] = Shelter_df['outcome_age_days'] - Shelter_df['time_in_shelter_days']

# Cleaning Up Breeds
Shelter_df["Breed"] = Shelter_df["breed"].str.split('/').str[0]
Shelter_df["Sub"] = Shelter_df["breed"].str.split('/').str[-1]

# Cleaned the Breeds to reclassify half/breeds as mixed 
condi = Shelter_df["breed"] == Shelter_df["Sub"]
anti_condi = Shelter_df["breed"] != Shelter_df["Sub"]
Shelter_df["Sub"] = Shelter_df.where(condi, " Mix " , axis=1) #used loops to both identify and rename breeds
Shelter_df["Sub"] = Shelter_df["Sub"].where(anti_condi, " ")  #ran inverse of condition to clear out unwanted strings
Shelter_df["Breed"] = Shelter_df["Breed"] + Shelter_df["Sub"]
    
# Dropped unwanted columns
Shelter_df = Shelter_df.drop(['animal_type', 'breed', 'Sub'], axis=1)

Shelter_df = Shelter_df.astype({"outcome_age_days": float})
Shelter_df.head()
# Out:
#    outcome_age_days     outcome_type         gender  time_in_shelter_days  \
# 0            3650.0  Return to Owner  Neutered Male              0.588194
# 1            2555.0  Return to Owner  Neutered Male              1.259722
# 2            2190.0  Return to Owner  Neutered Male              1.113889
# 3            3650.0         Transfer  Neutered Male              4.970139
# 4            5840.0  Return to Owner  Neutered Male              0.119444
#
#    intake_age_days                  Breed
# 0      3649.411806  Spinone Italiano Mix
# 1      2553.740278  Spinone Italiano Mix
# 2      2188.886111  Spinone Italiano Mix
# 3      3645.029861             Dachshund
# 4      5839.880556     Shetland Sheepdog

# %%
######## This is a mess and I need help formatting it correctly
### JSON Data and Target Columns
breed_cols = ["Affectionate with Family","Amount of Shedding","Friendly Toward Strangers",
              "Intelligence","Potential For Playfulness"]

all_dog_data_df = pd.merge(dogs_df, Shelter_df, on=["Breed"], how='outer')
all_dog_data_df
dog_data_counts = all_dog_data_df["Breed"].value_counts().sort_index(ascending=False).sort_values(ascending=False)
dog_data_counts
all_dog_data_df
# Out:
#                                    Breed  Adaptability  \
# 0                          Affenpinscher           3.0
# 1                           Afghan Hound           4.0
# 2                       Airedale Terrier           2.0
# 3                                  Akita           3.0
# 4                       Alaskan Klee Kai           3.0
# 5                       Alaskan Malamute           2.0
# 6                       American Bulldog           2.0
# 7             American English Coonhound           3.0
# 8                    American Eskimo Dog           4.0
# 9                      American Foxhound           2.0
# 10             American Pit Bull Terrier           3.0
# 11        American Staffordshire Terrier           2.0
# 12                American Water Spaniel           3.0
# 13                Anatolian Shepherd Dog           3.0
# 14               Appenzeller Sennenhunde           3.0
# 15                 Australian Cattle Dog           3.0
# 16                     Australian Kelpie           3.0
# 17                   Australian Shepherd           3.0
# 18                    Australian Terrier           3.0
# 19                               Azawakh           3.0
# 20                                Barbet           3.0
# 21                               Basenji           4.0
# 22                          Basset Hound           3.0
# 23                                Beagle           3.0
# 24                        Bearded Collie           3.0
# 25                    Bedlington Terrier           4.0
# 26                      Belgian Malinois           3.0
# 27                      Belgian Sheepdog           4.0
# 28                      Belgian Tervuren           3.0
# 29                         Berger Picard           4.0
# ...                                  ...           ...
# 45891                          Hovawart            NaN
# 45892                          Cockatoo            NaN
# 45893                          Cockatoo            NaN
# 45894                          Cockatoo            NaN
# 45895                             Heron            NaN
# 45896                             Heron            NaN
# 45897                      Cockatoo Mix            NaN
# 45898                       African Mix            NaN
# 45899                   Sussex Span Mix            NaN
# 45900                   Sussex Span Mix            NaN
# 45901              Lakeland Terrier Mix            NaN
# 45902  Grand Basset Griffon Vendeen Mix            NaN
# 45903                          Hawk Mix            NaN
# 45904                               Owl            NaN
# 45905                          Landseer            NaN
# 45906                   Barred Rock Mix            NaN
# 45907                          Crow Mix            NaN
# 45908                 Dogue De Bordeaux            NaN
# 45909                       Muscovy Mix            NaN
# 45910                       Muscovy Mix            NaN
# 45911                Smooth Fox Terrier            NaN
# 45912                           Muscovy            NaN
# 45913                           Muscovy            NaN
# 45914                     Song Bird Mix            NaN
# 45915                  Mexican Hairless            NaN
# 45916      Treeing Tennesse Brindle Mix            NaN
# 45917      Treeing Tennesse Brindle Mix            NaN
# 45918                Dandie Dinmont Mix            NaN
# 45919                      Pheasant Mix            NaN
# 45920                       Leghorn Mix            NaN
#
#        All Around Friendliness   Exercise Needs   Health Grooming  \
# 0                          3.0              4.0               2.0
# 1                          4.0              4.0               2.0
# 2                          4.0              5.0               3.0
# 3                          2.0              4.0               4.0
# 4                          3.0              4.0               3.0
# 5                          4.0              5.0               3.0
# 6                          3.0              4.0               3.0
# 7                          5.0              5.0               3.0
# 8                          5.0              4.0               3.0
# 9                          5.0              5.0               4.0
# 10                         4.0              5.0               3.0
# 11                         4.0              4.0               3.0
# 12                         4.0              4.0               3.0
# 13                         2.0              3.0               3.0
# 14                         4.0              4.0               3.0
# 15                         4.0              5.0               3.0
# 16                         3.0              4.0               3.0
# 17                         4.0              5.0               2.0
# 18                         3.0              5.0               3.0
# 19                         3.0              3.0               3.0
# 20                         4.0              4.0               2.0
# 21                         5.0              3.0               3.0
# 22                         5.0              2.0               4.0
# 23                         5.0              5.0               3.0
# 24                         5.0              4.0               3.0
# 25                         5.0              4.0               3.0
# 26                         4.0              5.0               3.0
# 27                         5.0              5.0               3.0
# 28                         3.0              4.0               3.0
# 29                         4.0              5.0               4.0
# ...                        ...              ...               ...
# 45891                      NaN              NaN               NaN
# 45892                      NaN              NaN               NaN
# 45893                      NaN              NaN               NaN
# 45894                      NaN              NaN               NaN
# 45895                      NaN              NaN               NaN
# 45896                      NaN              NaN               NaN
# 45897                      NaN              NaN               NaN
# 45898                      NaN              NaN               NaN
# 45899                      NaN              NaN               NaN
# 45900                      NaN              NaN               NaN
# 45901                      NaN              NaN               NaN
# 45902                      NaN              NaN               NaN
# 45903                      NaN              NaN               NaN
# 45904                      NaN              NaN               NaN
# 45905                      NaN              NaN               NaN
# 45906                      NaN              NaN               NaN
# 45907                      NaN              NaN               NaN
# 45908                      NaN              NaN               NaN
# 45909                      NaN              NaN               NaN
# 45910                      NaN              NaN               NaN
# 45911                      NaN              NaN               NaN
# 45912                      NaN              NaN               NaN
# 45913                      NaN              NaN               NaN
# 45914                      NaN              NaN               NaN
# 45915                      NaN              NaN               NaN
# 45916                      NaN              NaN               NaN
# 45917                      NaN              NaN               NaN
# 45918                      NaN              NaN               NaN
# 45919                      NaN              NaN               NaN
# 45920                      NaN              NaN               NaN
#
#         Trainability  Adapts Well to Apartment Living  \
# 0                3.0                              5.0
# 1                3.0                              5.0
# 2                5.0                              1.0
# 3                4.0                              2.0
# 4                4.0                              3.0
# 5                4.0                              1.0
# 6                3.0                              1.0
# 7                5.0                              1.0
# 8                4.0                              5.0
# 9                4.0                              1.0
# 10               4.0                              3.0
# 11               4.0                              2.0
# 12               4.0                              2.0
# 13               3.0                              1.0
# 14               4.0                              1.0
# 15               4.0                              2.0
# 16               5.0                              2.0
# 17               5.0                              1.0
# 18               4.0                              5.0
# 19               3.0                              5.0
# 20               3.0                              3.0
# 21               4.0                              5.0
# 22               4.0                              5.0
# 23               4.0                              4.0
# 24               4.0                              3.0
# 25               4.0                              4.0
# 26               4.0                              1.0
# 27               4.0                              3.0
# 28               4.0                              3.0
# 29               3.0                              3.0
# ...              ...                              ...
# 45891            NaN                              NaN
# 45892            NaN                              NaN
# 45893            NaN                              NaN
# 45894            NaN                              NaN
# 45895            NaN                              NaN
# 45896            NaN                              NaN
# 45897            NaN                              NaN
# 45898            NaN                              NaN
# 45899            NaN                              NaN
# 45900            NaN                              NaN
# 45901            NaN                              NaN
# 45902            NaN                              NaN
# 45903            NaN                              NaN
# 45904            NaN                              NaN
# 45905            NaN                              NaN
# 45906            NaN                              NaN
# 45907            NaN                              NaN
# 45908            NaN                              NaN
# 45909            NaN                              NaN
# 45910            NaN                              NaN
# 45911            NaN                              NaN
# 45912            NaN                              NaN
# 45913            NaN                              NaN
# 45914            NaN                              NaN
# 45915            NaN                              NaN
# 45916            NaN                              NaN
# 45917            NaN                              NaN
# 45918            NaN                              NaN
# 45919            NaN                              NaN
# 45920            NaN                              NaN
#
#        Affectionate with Family  Amount Of Shedding  Dog Friendly  \
# 0                           5.0                 1.0           4.0
# 1                           5.0                 4.0           4.0
# 2                           4.0                 2.0           4.0
# 3                           5.0                 5.0           1.0
# 4                           4.0                 4.0           2.0
# 5                           4.0                 5.0           2.0
# 6                           5.0                 1.0           2.0
# 7                           5.0                 3.0           4.0
# 8                           5.0                 5.0           5.0
# 9                           4.0                 3.0           5.0
# 10                          5.0                 4.0           1.0
# 11                          4.0                 2.0           2.0
# 12                          5.0                 3.0           2.0
# 13                          3.0                 2.0           2.0
# 14                          5.0                 3.0           3.0
# 15                          5.0                 3.0           4.0
# 16                          4.0                 3.0           3.0
# 17                          5.0                 3.0           5.0
# 18                          4.0                 1.0           2.0
# 19                          4.0                 3.0           3.0
# 20                          5.0                 2.0           4.0
# 21                          5.0                 1.0           4.0
# 22                          5.0                 4.0           5.0
# 23                          5.0                 3.0           5.0
# 24                          5.0                 4.0           5.0
# 25                          5.0                 5.0           4.0
# 26                          5.0                 2.0           2.0
# 27                          4.0                 5.0           5.0
# 28                          4.0                 4.0           3.0
# 29                          5.0                 4.0           3.0
# ...                         ...                 ...           ...
# 45891                       NaN                 NaN           NaN
# 45892                       NaN                 NaN           NaN
# 45893                       NaN                 NaN           NaN
# 45894                       NaN                 NaN           NaN
# 45895                       NaN                 NaN           NaN
# 45896                       NaN                 NaN           NaN
# 45897                       NaN                 NaN           NaN
# 45898                       NaN                 NaN           NaN
# 45899                       NaN                 NaN           NaN
# 45900                       NaN                 NaN           NaN
# 45901                       NaN                 NaN           NaN
# 45902                       NaN                 NaN           NaN
# 45903                       NaN                 NaN           NaN
# 45904                       NaN                 NaN           NaN
# 45905                       NaN                 NaN           NaN
# 45906                       NaN                 NaN           NaN
# 45907                       NaN                 NaN           NaN
# 45908                       NaN                 NaN           NaN
# 45909                       NaN                 NaN           NaN
# 45910                       NaN                 NaN           NaN
# 45911                       NaN                 NaN           NaN
# 45912                       NaN                 NaN           NaN
# 45913                       NaN                 NaN           NaN
# 45914                       NaN                 NaN           NaN
# 45915                       NaN                 NaN           NaN
# 45916                       NaN                 NaN           NaN
# 45917                       NaN                 NaN           NaN
# 45918                       NaN                 NaN           NaN
# 45919                       NaN                 NaN           NaN
# 45920                       NaN                 NaN           NaN
#
#             ...         Tendency To Bark Or Howl  Tolerates Being Alone  \
# 0           ...                              2.0                    1.0
# 1           ...                              2.0                    2.0
# 2           ...                              4.0                    2.0
# 3           ...                              5.0                    1.0
# 4           ...                              3.0                    2.0
# 5           ...                              5.0                    1.0
# 6           ...                              2.0                    1.0
# 7           ...                              5.0                    2.0
# 8           ...                              4.0                    2.0
# 9           ...                              5.0                    1.0
# 10          ...                              3.0                    1.0
# 11          ...                              4.0                    2.0
# 12          ...                              3.0                    1.0
# 13          ...                              2.0                    3.0
# 14          ...                              5.0                    1.0
# 15          ...                              2.0                    3.0
# 16          ...                              4.0                    2.0
# 17          ...                              4.0                    2.0
# 18          ...                              5.0                    2.0
# 19          ...                              1.0                    3.0
# 20          ...                              3.0                    1.0
# 21          ...                              1.0                    4.0
# 22          ...                              4.0                    3.0
# 23          ...                              5.0                    1.0
# 24          ...                              3.0                    2.0
# 25          ...                              3.0                    3.0
# 26          ...                              2.0                    3.0
# 27          ...                              1.0                    3.0
# 28          ...                              5.0                    1.0
# 29          ...                              2.0                    3.0
# ...         ...                              ...                    ...
# 45891       ...                              NaN                    NaN
# 45892       ...                              NaN                    NaN
# 45893       ...                              NaN                    NaN
# 45894       ...                              NaN                    NaN
# 45895       ...                              NaN                    NaN
# 45896       ...                              NaN                    NaN
# 45897       ...                              NaN                    NaN
# 45898       ...                              NaN                    NaN
# 45899       ...                              NaN                    NaN
# 45900       ...                              NaN                    NaN
# 45901       ...                              NaN                    NaN
# 45902       ...                              NaN                    NaN
# 45903       ...                              NaN                    NaN
# 45904       ...                              NaN                    NaN
# 45905       ...                              NaN                    NaN
# 45906       ...                              NaN                    NaN
# 45907       ...                              NaN                    NaN
# 45908       ...                              NaN                    NaN
# 45909       ...                              NaN                    NaN
# 45910       ...                              NaN                    NaN
# 45911       ...                              NaN                    NaN
# 45912       ...                              NaN                    NaN
# 45913       ...                              NaN                    NaN
# 45914       ...                              NaN                    NaN
# 45915       ...                              NaN                    NaN
# 45916       ...                              NaN                    NaN
# 45917       ...                              NaN                    NaN
# 45918       ...                              NaN                    NaN
# 45919       ...                              NaN                    NaN
# 45920       ...                              NaN                    NaN
#
#        Tolerates Cold Weather  Tolerates Hot Weather  Wanderlust Potential  \
# 0                         3.0                    3.0                   2.0
# 1                         5.0                    5.0                   5.0
# 2                         3.0                    3.0                   4.0
# 3                         5.0                    2.0                   4.0
# 4                         5.0                    2.0                   4.0
# 5                         5.0                    2.0                   5.0
# 6                         2.0                    2.0                   3.0
# 7                         4.0                    4.0                   5.0
# 8                         5.0                    3.0                   3.0
# 9                         4.0                    4.0                   5.0
# 10                        2.0                    3.0                   4.0
# 11                        2.0                    3.0                   3.0
# 12                        2.0                    4.0                   5.0
# 13                        5.0                    3.0                   4.0
# 14                        5.0                    4.0                   3.0
# 15                        4.0                    4.0                   4.0
# 16                        3.0                    5.0                   4.0
# 17                        4.0                    4.0                   5.0
# 18                        3.0                    4.0                   4.0
# 19                        1.0                    5.0                   2.0
# 20                        4.0                    4.0                   3.0
# 21                        1.0                    4.0                   5.0
# 22                        2.0                    2.0                   5.0
# 23                        2.0                    4.0                   5.0
# 24                        4.0                    3.0                   5.0
# 25                        4.0                    3.0                   4.0
# 26                        4.0                    4.0                   3.0
# 27                        4.0                    3.0                   4.0
# 28                        4.0                    3.0                   4.0
# 29                        4.0                    3.0                   2.0
# ...                       ...                    ...                   ...
# 45891                     NaN                    NaN                   NaN
# 45892                     NaN                    NaN                   NaN
# 45893                     NaN                    NaN                   NaN
# 45894                     NaN                    NaN                   NaN
# 45895                     NaN                    NaN                   NaN
# 45896                     NaN                    NaN                   NaN
# 45897                     NaN                    NaN                   NaN
# 45898                     NaN                    NaN                   NaN
# 45899                     NaN                    NaN                   NaN
# 45900                     NaN                    NaN                   NaN
# 45901                     NaN                    NaN                   NaN
# 45902                     NaN                    NaN                   NaN
# 45903                     NaN                    NaN                   NaN
# 45904                     NaN                    NaN                   NaN
# 45905                     NaN                    NaN                   NaN
# 45906                     NaN                    NaN                   NaN
# 45907                     NaN                    NaN                   NaN
# 45908                     NaN                    NaN                   NaN
# 45909                     NaN                    NaN                   NaN
# 45910                     NaN                    NaN                   NaN
# 45911                     NaN                    NaN                   NaN
# 45912                     NaN                    NaN                   NaN
# 45913                     NaN                    NaN                   NaN
# 45914                     NaN                    NaN                   NaN
# 45915                     NaN                    NaN                   NaN
# 45916                     NaN                    NaN                   NaN
# 45917                     NaN                    NaN                   NaN
# 45918                     NaN                    NaN                   NaN
# 45919                     NaN                    NaN                   NaN
# 45920                     NaN                    NaN                   NaN
#
#        outcome_age_days     outcome_type         gender  time_in_shelter_days  \
# 0                   NaN              NaN            NaN                   NaN
# 1                   NaN              NaN            NaN                   NaN
# 2                   NaN              NaN            NaN                   NaN
# 3                   NaN              NaN            NaN                   NaN
# 4                   NaN              NaN            NaN                   NaN
# 5                   NaN              NaN            NaN                   NaN
# 6                   NaN              NaN            NaN                   NaN
# 7                   NaN              NaN            NaN                   NaN
# 8                   NaN              NaN            NaN                   NaN
# 9                   NaN              NaN            NaN                   NaN
# 10                  NaN              NaN            NaN                   NaN
# 11                  NaN              NaN            NaN                   NaN
# 12                  NaN              NaN            NaN                   NaN
# 13                  NaN              NaN            NaN                   NaN
# 14                  NaN              NaN            NaN                   NaN
# 15                  NaN              NaN            NaN                   NaN
# 16                  NaN              NaN            NaN                   NaN
# 17                  NaN              NaN            NaN                   NaN
# 18                  NaN              NaN            NaN                   NaN
# 19                  NaN              NaN            NaN                   NaN
# 20                  NaN              NaN            NaN                   NaN
# 21                  NaN              NaN            NaN                   NaN
# 22                  NaN              NaN            NaN                   NaN
# 23                  NaN              NaN            NaN                   NaN
# 24                  NaN              NaN            NaN                   NaN
# 25                  NaN              NaN            NaN                   NaN
# 26                  NaN              NaN            NaN                   NaN
# 27                  NaN              NaN            NaN                   NaN
# 28                  NaN              NaN            NaN                   NaN
# 29                  NaN              NaN            NaN                   NaN
# ...                 ...              ...            ...                   ...
# 45891             365.0         Adoption  Neutered Male              8.254861
# 45892            1460.0         Adoption  Intact Female              1.898611
# 45893            7300.0         Transfer    Intact Male              4.378472
# 45894            9125.0         Transfer  Intact Female              4.378472
# 45895            1825.0       Euthanasia        Unknown              0.061806
# 45896             365.0       Euthanasia        Unknown              0.006250
# 45897             365.0         Adoption        Unknown              5.909722
# 45898             365.0  Return to Owner        Unknown              1.019444
# 45899            1095.0             Died    Intact Male              5.221528
# 45900            1825.0         Transfer  Spayed Female              4.243056
# 45901            2190.0         Adoption  Neutered Male              4.021528
# 45902              60.0         Adoption  Neutered Male              5.075694
# 45903             730.0         Transfer        Unknown              0.833333
# 45904             365.0       Euthanasia        Unknown              0.006944
# 45905            1460.0         Transfer  Intact Female              3.098611
# 45906             365.0         Transfer    Intact Male              7.945833
# 45907             730.0         Relocate        Unknown              0.056250
# 45908             365.0         Transfer  Neutered Male              7.743750
# 45909             180.0  Return to Owner  Intact Female              1.149306
# 45910             365.0         Transfer        Unknown              3.065972
# 45911             365.0         Adoption  Spayed Female             13.981944
# 45912             730.0         Adoption        Unknown             10.166667
# 45913            1095.0         Transfer        Unknown              2.949306
# 45914             150.0       Euthanasia        Unknown              0.010417
# 45915            1095.0  Return to Owner  Spayed Female              1.895833
# 45916             270.0         Adoption  Neutered Male              8.177778
# 45917             730.0         Adoption  Spayed Female             25.840278
# 45918            2190.0         Adoption  Spayed Female              6.232639
# 45919             730.0         Transfer        Unknown              3.068056
# 45920             365.0         Transfer  Intact Female              2.980556
#
#        intake_age_days
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# ...                ...
# 45891       356.745139
# 45892      1458.101389
# 45893      7295.621528
# 45894      9120.621528
# 45895      1824.938194
# 45896       364.993750
# 45897       359.090278
# 45898       363.980556
# 45899      1089.778472
# 45900      1820.756944
# 45901      2185.978472
# 45902        54.924306
# 45903       729.166667
# 45904       364.993056
# 45905      1456.901389
# 45906       357.054167
# 45907       729.943750
# 45908       357.256250
# 45909       178.850694
# 45910       361.934028
# 45911       351.018056
# 45912       719.833333
# 45913      1092.050694
# 45914       149.989583
# 45915      1093.104167
# 45916       261.822222
# 45917       704.159722
# 45918      2183.767361
# 45919       726.931944
# 45920       362.019444
#
# [45921 rows x 37 columns]

# %%
######## This is a mess and I need help formatting it correctly
connection_string = "root:PyroManic777!@localhost:3306/shelter"
engine = create_engine(f'mysql://{connection_string}')
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-53-7c1459963fc4> in <module>
#       1 ######## This is a mess and I need help formatting it correctly
#       2 connection_string = "root:PyroManic777!@localhost:3306/shelter"
# ----> 3 engine = create_engine(f'mysql://{connection_string}')
#       4 engine.table_names()
#
# ~\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     421     strategy = kwargs.pop("strategy", default_strategy)
#     422     strategy = strategies.strategies[strategy]
# --> 423     return strategy.create(*args, **kwargs)
#     424
#     425
#
# ~\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ~\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in dbapi(cls)
#     116     @classmethod
#     117     def dbapi(cls):
# --> 118         return __import__("MySQLdb")
#     119
#     120     def do_ping(self, dbapi_connection):
#
# ModuleNotFoundError: No module named 'MySQLdb'
